# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('euro2012.csv') 
data_euro = pd.DataFrame(data)
data_euro
# Out:
#     Unnamed: 0                 Team  Goals  Shots on target  Shots off target  \
# 0            0              Croatia      4               13                12
# 1            1       Czech Republic      4               13                18
# 2            2              Denmark      4               10                10
# 3            3              England      5               11                18
# 4            4               France      3               22                24
# 5            5              Germany     10               32                32
# 6            6               Greece      5                8                18
# 7            7                Italy      6               34                45
# 8            8          Netherlands      2               12                36
# 9            9               Poland      2               15                23
# 10          10             Portugal      6               22                42
# ...

# %%
type(data_euro)
# Out:
# pandas.core.frame.DataFrame

# %%
data_euro.shape
# Out:
# (16, 36)

# %%
data_euro.columns
# Out:
# Index(['Unnamed: 0', 'Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
#        'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
#        'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
#        'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
#        'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
#        'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
#        'Offsides', 'Yellow Cards', 'Red Cards', 'Subs on', 'Subs off',
#        'Players Used'],
#       dtype='object')

# %% [markdown]
# ### 1

# %%
data['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# ### 2

# %%
print('số độit ham gia Euro2012 là: ',len(data['Team']))
# Out:
# số độit ham gia Euro2012 là:  16

# %% [markdown]
# ### 3

# %%
data_euro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  16 non-null     int64
#  1   Team                        16 non-null     object
#  2   Goals                       16 non-null     int64
#  3   Shots on target             16 non-null     int64
#  4   Shots off target            16 non-null     int64
#  5   Shooting Accuracy           16 non-null     object
#  6   % Goals-to-shots            16 non-null     object
#  7   Total shots (inc. Blocked)  16 non-null     int64
#  8   Hit Woodwork                16 non-null     int64
#  9   Penalty goals               16 non-null     int64
#  10  Penalties not scored        16 non-null     int64
#  11  Headed goals                16 non-null     int64
#  12  Passes                      16 non-null     int64
# ...

# %% [markdown]
# ### 4

# %%
discipline = data_euro[['Team','Yellow Cards','Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# ### 5

# %%
discipline.sort_values(['Red Cards','Yellow Cards'],ascending=False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %% [markdown]
# ### 6

# %%
np.mean(discipline['Yellow Cards'])
# Out:
# 7.4375

# %%
data_euro[data_euro['Goals']>6]
# Out:
#     Unnamed: 0     Team  Goals  Shots on target  Shots off target  \
# 5            5  Germany     10               32                32
# 13          13    Spain     12               42                33
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 5             47.80%           15.60%                          80
# 13            55.90%           16.00%                         100
#
#     Hit Woodwork  Penalty goals  ...  Saves made  Saves-to-shots ratio  \
# 5              2              1  ...          10                62.60%
# 13             0              1  ...          15                93.80%
#
#     Fouls Won  Fouls Conceded Offsides  Yellow Cards  Red Cards  Subs on  \
# 5          63              49       12             4          0       15
# 13        102              83       19            11          0       17
#
#     Subs off  Players Used
# 5         15            17
# 13        17            18
#
# [2 rows x 36 columns]

# %% [markdown]
# ### 7

# %%
data_euro[data_euro['Team'].str.startswith('G')]
# Out:
#    Unnamed: 0     Team  Goals  Shots on target  Shots off target  \
# 5           5  Germany     10               32                32
# 6           6   Greece      5                8                18
#
#   Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 5            47.80%           15.60%                          80
# 6            30.70%           19.20%                          32
#
#    Hit Woodwork  Penalty goals  ...  Saves made  Saves-to-shots ratio  \
# 5             2              1  ...          10                62.60%
# 6             1              1  ...          13                65.10%
#
#    Fouls Won  Fouls Conceded Offsides  Yellow Cards  Red Cards  Subs on  \
# 5         63              49       12             4          0       15
# 6         67              48       12             9          1       12
#
#    Subs off  Players Used
# 5        15            17
# 6        12            20
#
# [2 rows x 36 columns]

# %% [markdown]
# ### 8

# %%
data_euro.iloc[:,0:7]
# Out:
#     Unnamed: 0                 Team  Goals  Shots on target  Shots off target  \
# 0            0              Croatia      4               13                12
# 1            1       Czech Republic      4               13                18
# 2            2              Denmark      4               10                10
# 3            3              England      5               11                18
# 4            4               France      3               22                24
# 5            5              Germany     10               32                32
# 6            6               Greece      5                8                18
# 7            7                Italy      6               34                45
# 8            8          Netherlands      2               12                36
# 9            9               Poland      2               15                23
# 10          10             Portugal      6               22                42
# ...

# %% [markdown]
# ### 9

# %%
data_euro.iloc[:,0:-3]
# Out:
#     Unnamed: 0                 Team  Goals  Shots on target  Shots off target  \
# 0            0              Croatia      4               13                12
# 1            1       Czech Republic      4               13                18
# 2            2              Denmark      4               10                10
# 3            3              England      5               11                18
# 4            4               France      3               22                24
# 5            5              Germany     10               32                32
# 6            6               Greece      5                8                18
# 7            7                Italy      6               34                45
# 8            8          Netherlands      2               12                36
# 9            9               Poland      2               15                23
# 10          10             Portugal      6               22                42
# ...

# %% [markdown]
# ### 10

# %%
data_euro[['Team','Goals','Shooting Accuracy','Yellow Cards','Red Cards']]
# Out:
#                    Team  Goals Shooting Accuracy  Yellow Cards  Red Cards
# 0               Croatia      4            51.90%             9          0
# 1        Czech Republic      4            41.90%             7          0
# 2               Denmark      4            50.00%             4          0
# 3               England      5            50.00%             5          0
# 4                France      3            37.90%             6          0
# 5               Germany     10            47.80%             4          0
# 6                Greece      5            30.70%             9          1
# 7                 Italy      6            43.00%            16          0
# 8           Netherlands      2            25.00%             5          0
# 9                Poland      2            39.40%             7          1
# 10             Portugal      6            34.30%            12          0
# 11  Republic of Ireland      1            36.80%             6          1
# ...

# %% [markdown]
# ### 11

# %%
data_euro_index = data_euro.set_index('Team')
data_euro_index
# Out:
#                      Unnamed: 0  Goals  Shots on target  Shots off target  \
# Team
# Croatia                       0      4               13                12
# Czech Republic                1      4               13                18
# Denmark                       2      4               10                10
# England                       3      5               11                18
# France                        4      3               22                24
# Germany                       5     10               32                32
# Greece                        6      5                8                18
# Italy                         7      6               34                45
# Netherlands                   8      2               12                36
# Poland                        9      2               15                23
# Portugal                     10      6               22                42
# Republic of Ireland          11      1                7                12
# ...

# %%
data_euro_index.loc[['England','Italy','Russia'],
              ['Shooting Accuracy','Goals']]
# Out:
#         Shooting Accuracy  Goals
# Team
# England            50.00%      5
# Italy              43.00%      6
# Russia             22.50%      5
